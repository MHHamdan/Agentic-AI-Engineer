# %% [markdown]
# # Webhooks Lab
# This notebook shows webhook request validation logic.

# %%
from webhook_demo import verify_signature
payload = b'{"event_type": "update", "resource_id": 1}'
signature = '193667dffb375ba10b9b3da4818797c724f04e4cd15a496e1b062526167a1bff'
print(verify_signature(payload, signature))
